# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from statevectorsim import *
from statevectorsim.test_suite import *
import math
from benchmark import *

# %%
# Define the range of qubits to test.
MAX_NUM_QUBITS = 7
# Define the range of qubits to test.
QUBIT_RANGE = list(range(2, MAX_NUM_QUBITS+1))  # 2 to 7 qubits (2^7 = 128 dimensions max)
NUM_SHOTS = 128

print("Starting QFT Benchmarking (including Qiskit-based Hybrid Method)...")

# Run the benchmark
benchmark_results = benchmark_qft(QUBIT_RANGE, NUM_SHOTS)
# Out:
# Starting QFT Benchmarking (including Qiskit-based Hybrid Method)...
#
# --- Benchmarking QFT on 2 Qubits (State Space: 2^2=4) ---
# Tensor Only (Forced): Avg time over 128 shots: 0.000040 s
# Bitmask Only (Forced): Avg time over 128 shots: 0.000032 s
# Qiskit Aer Statevector: Avg time over 128 shots: 0.000922 s
#
# --- Benchmarking QFT on 3 Qubits (State Space: 2^3=8) ---
# Tensor Only (Forced): Avg time over 128 shots: 0.000256 s
# Bitmask Only (Forced): Avg time over 128 shots: 0.000264 s
# Qiskit Aer Statevector: Avg time over 128 shots: 0.002384 s
#
# --- Benchmarking QFT on 4 Qubits (State Space: 2^4=16) ---
# Tensor Only (Forced): Avg time over 128 shots: 0.000494 s
# Bitmask Only (Forced): Avg time over 128 shots: 0.001078 s
# Qiskit Aer Statevector: Avg time over 128 shots: 0.002535 s
#
# --- Benchmarking QFT on 5 Qubits (State Space: 2^5=32) ---
# Tensor Only (Forced): Avg time over 128 shots: 0.000639 s
# Bitmask Only (Forced): Avg time over 128 shots: 0.001910 s
# Qiskit Aer Statevector: Avg time over 128 shots: 0.002591 s
#
# --- Benchmarking QFT on 6 Qubits (State Space: 2^6=64) ---
# Tensor Only (Forced): Avg time over 128 shots: 0.000956 s
# Bitmask Only (Forced): Avg time over 128 shots: 0.004945 s
# Qiskit Aer Statevector: Avg time over 128 shots: 0.002934 s
#
# --- Benchmarking QFT on 7 Qubits (State Space: 2^7=128) ---
# Tensor Only (Forced): Avg time over 128 shots: 0.001247 s
# Bitmask Only (Forced): Avg time over 128 shots: 0.014598 s
# Qiskit Aer Statevector: Avg time over 128 shots: 0.004799 s

# %%
# Plot the results
plot_benchmarks(benchmark_results, NUM_SHOTS, QUBIT_RANGE[-1])

# %%
from statevectorsim import *
from statevectorsim.test_suite import *
import math
from benchmark import *

# %%
# Define the range of qubits to test.
MAX_NUM_QUBITS = 7
# Define the range of qubits to test.
QUBIT_RANGE = list(range(1, MAX_NUM_QUBITS+1))  # 2 to 7 qubits (2^7 = 128 dimensions max)
NUM_SHOTS = 128

print("Starting QPE Benchmarking (including Qiskit-based Hybrid Method)...")

# Run the benchmark
benchmark_results = benchmark_qpe(QUBIT_RANGE, NUM_SHOTS)
# Out:
# Starting QPE Benchmarking (including Qiskit-based Hybrid Method)...
#
# --- Benchmarking QPE on 1 Estimation Qubits (2 Total Qubits) ---
# Tensor Only (Forced): Avg time over 128 shots: 0.000206 s
# Bitmask Only (Forced): Avg time over 128 shots: 0.000134 s
# Qiskit Aer Statevector: Avg time over 128 shots: 0.001608 s
#
# --- Benchmarking QPE on 2 Estimation Qubits (3 Total Qubits) ---
# Tensor Only (Forced): Avg time over 128 shots: 0.000368 s
# Bitmask Only (Forced): Avg time over 128 shots: 0.000305 s
# Qiskit Aer Statevector: Avg time over 128 shots: 0.001722 s
#
# --- Benchmarking QPE on 3 Estimation Qubits (4 Total Qubits) ---
# Tensor Only (Forced): Avg time over 128 shots: 0.000524 s
# Bitmask Only (Forced): Avg time over 128 shots: 0.001018 s
# Qiskit Aer Statevector: Avg time over 128 shots: 0.001831 s
#
# --- Benchmarking QPE on 4 Estimation Qubits (5 Total Qubits) ---
# Tensor Only (Forced): Avg time over 128 shots: 0.000704 s
# Bitmask Only (Forced): Avg time over 128 shots: 0.002344 s
# Qiskit Aer Statevector: Avg time over 128 shots: 0.002388 s
#
# --- Benchmarking QPE on 5 Estimation Qubits (6 Total Qubits) ---
# Tensor Only (Forced): Avg time over 128 shots: 0.000999 s
# Bitmask Only (Forced): Avg time over 128 shots: 0.005909 s
# Qiskit Aer Statevector: Avg time over 128 shots: 0.003009 s
#
# --- Benchmarking QPE on 6 Estimation Qubits (7 Total Qubits) ---
# Tensor Only (Forced): Avg time over 128 shots: 0.001500 s
# Bitmask Only (Forced): Avg time over 128 shots: 0.014567 s
# Qiskit Aer Statevector: Avg time over 128 shots: 0.003862 s
#
# --- Benchmarking QPE on 7 Estimation Qubits (8 Total Qubits) ---
# Tensor Only (Forced): Avg time over 128 shots: 0.002386 s
# Bitmask Only (Forced): Avg time over 128 shots: 0.039985 s
# Qiskit Aer Statevector: Avg time over 128 shots: 0.004590 s

# %%
# Plot the results
plot_benchmarks(benchmark_results, NUM_SHOTS, QUBIT_RANGE[-1], 'QPE')
