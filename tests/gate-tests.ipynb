# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tests.test_suite import *

# %%
test_all_gates()
# Out:
# ...
#    QUANTUM GATE FUNCTIONAL AND BLOCH SPHERE VISUALIZATION TESTS
# ...
# RUNNING TEST: 1. I Gate: |0> -> |0> (1 Qubits)
# Applying Gates...
# Final State Vector: [1.+0.j 0.+0.j]
# Plotting Bloch Spheres for 1 Qubits...
# ----------------------------------------------------------------------
# ...
# RUNNING TEST: 2. X Gate: |0> -> |1> (+Z to -Z) (1 Qubits)
# Applying Gates...
# Final State Vector: [0.+0.j 1.+0.j]
# Plotting Bloch Spheres for 1 Qubits...
# ----------------------------------------------------------------------
# ...
# RUNNING TEST: 3. Y Gate: |0> -> i|1> (+Z to -Z, with global phase) (1 Qubits)
# Applying Gates...
# Final State Vector: [0.+0.j 0.+1.j]
# Plotting Bloch Spheres for 1 Qubits...
# ----------------------------------------------------------------------
# ...
# RUNNING TEST: 4. Z Gate: |0> -> |0> (1 Qubits)
# Applying Gates...
# Final State Vector: [1.+0.j 0.+0.j]
# Plotting Bloch Spheres for 1 Qubits...
# ----------------------------------------------------------------------
# ...
