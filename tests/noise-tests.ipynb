# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tests.test_suite import *

# %%
test_quantum_noise()
# Out:
# ...
#    RUNNING COMPREHENSIVE QUANTUM NOISE TESTS
# ...
#
# --- [1] BIT FLIP NOISE (X Error) ---
# Applying Bit Flip Noise (p=0.2) to |0> state...
# Counts: {'1': 614, '0': 2386}, Measured Error Rate: 0.2047 (Expected ~0.2)
# PASS: True
#
# --- [2] PHASE FLIP NOISE (Z Error) ---
# Applying Phase Flip Noise (p=0.15) to |+> state...
# Counts: {'0': 2557, '1': 443}, Measured Error Rate: 0.1477 (Expected ~0.15)
# PASS: True
#
# --- [3] DEPOLARIZING NOISE ---
# Applying Depolarizing Noise (p=0.3) to |0> state...
# Counts: {'1': 602, '0': 2398}, Measured Prob(|1>): 0.2007 (Expected 2p/3 = 0.2000)
# PASS: True
#
# --- [4] AUTOMATIC NOISE INJECTION (Bell State) ---
# Injected Depolarizing Noise (p=0.1) via NoiseModel.
# Clean Gates: 2 -> Noisy Gates: 5
# Counts: {'11': 1288, '00': 1346, '01': 184, '10': 182}
# PASS: Errors detected (Noise injection working).
# ----------------------------------------------------------------------

# %%
test_noise_qft_iqft()
# Out:
# ...
# RUNNING TEST: NOISE VISUALIZATION (QFT Round-Trip)
# Circuit: QFT(3) + Inverse QFT(3). Total Gates: 12
# Simulating 2000 shots with Depolarizing Noise (p=0.02)...
# Success Rate (|000>): 78.90% (Ideal 100%)
# Measurement Counts: {'000': 1578, '010': 92, '110': 50, '001': 88, '100': 130, '101': 17, '011': 12, '111': 33}
# ----------------------------------------------------------------------
